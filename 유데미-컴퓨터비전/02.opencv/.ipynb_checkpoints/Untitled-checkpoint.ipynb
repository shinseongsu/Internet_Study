# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread('DATA/puppy.jpeg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
# 경로에 이미지 없을 경우
img = cv2.imread('wrong/path/doesnot/ginwogowgai/jpg')

# %%
type(img)
# Out:
# NoneType

# %%
img = cv2.imread('DATA/puppy.jpeg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img
# Out:
# array([[[222, 233, 231],
#         [222, 233, 231],
#         [222, 233, 231],
#         ...,
#         [191, 202, 210],
#         [194, 205, 213],
#         [194, 205, 213]],
#
#        [[222, 233, 231],
#         [222, 233, 231],
#         [222, 233, 231],
#         ...,
#         [191, 202, 210],
#         [194, 205, 213],
#         [194, 205, 213]],
#
#        [[222, 233, 231],
#         [222, 233, 231],
#         [222, 233, 231],
#         ...,
#         [191, 202, 210],
#         [194, 205, 213],
#         [194, 205, 213]],
#
#        ...,
#
#        [[179, 162, 165],
#         [181, 164, 167],
#         [184, 167, 170],
#         ...,
#         [201, 201, 201],
#         [201, 201, 201],
#         [201, 201, 201]],
#
#        [[179, 162, 165],
#         [181, 164, 167],
#         [184, 167, 170],
#         ...,
#         [201, 201, 201],
#         [201, 201, 201],
#         [201, 201, 201]],
#
#        [[179, 162, 165],
#         [181, 164, 167],
#         [184, 167, 170],
# ...

# %%
img.shape
# Out:
# (924, 1386, 3)

# %%
plt.imshow(img)

# %%
# MATPLOTLIB --> RGB RED GREEN BLUE
# OPENCV --> BLUE GREEN RED

# %%
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
img_gray = cv2.imread('DATA/puppy.jpeg', cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img)

# %%
fix_img.shape
# Out:
# (924, 1386, 3)

# %%
new_img = cv2.resize(fix_img, (1000, 400))

# %%
plt.imshow(new_img)
