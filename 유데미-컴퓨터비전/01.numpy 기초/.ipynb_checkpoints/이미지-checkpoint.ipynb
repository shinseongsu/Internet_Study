# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
pic = Image.open('DATA/puppy.jpeg')

# %%
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1386x924 at 0x7F8A8A041DF0>

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr = np.asarray(pic)

# %%
pic_arr.shape
# Out:
# (924, 1386, 3)

# %%
plt.imshow(pic_arr)

# %%
pic_red = pic_arr.copy()

# %%
plt.imshow(pic_red)

# %%
pic_red.shape
# Out:
# (924, 1386, 3)

# %%
# R G B
plt.imshow(pic_red[:,:,0])

# %%
pic_red[:,:,1]
# Out:
# array([[233, 233, 233, ..., 202, 205, 205],
#        [233, 233, 233, ..., 202, 205, 205],
#        [233, 233, 233, ..., 202, 205, 205],
#        ...,
#        [162, 164, 167, ..., 201, 201, 201],
#        [162, 164, 167, ..., 201, 201, 201],
#        [162, 164, 167, ..., 201, 201, 201]], dtype=uint8)

# %%
plt.imshow(pic_red[:,:,0], cmap='gray')

# %%
plt.imshow(pic_red[:,:,1], cmap='gray')

# %%
plt.imshow(pic_red[:,:,2], cmap='gray')

# %%
pic_red[:,:,1] = 0

# %%
pic_red[:,:,2] = 0

# %%
plt.imshow(pic_red)

# %%
pic_red.shape
# Out:
# (924, 1386, 3)

# %%
pic_red[:,:,0].shape
# Out:
# (924, 1386)
